# %%
class Mine_operator:
    def __init__(self, operator_id, list_cars, name, location):
        self.operator_id = operator_id

    def add_driver(self, car, driver):
        car.driver = driver

    def finish_car(self, car, driver):
        pass

    def repair_car(self, car):
        pass

class Driver:
    def __init__(self, id, surname, name, number, car, status):
        self.driver_id = driver_id
        self.surname = surname
        self.name = name
        self.radio_number = radio_number
        self.car = car
        self.status = bool

class Car:
    def __init__(self, car_id, coordinates, driver):
        self.car_id = car_id
        self.coordinates = Coordinates
        self.driver = Driver
        self.model = model
        self.firm = firm


class Small_Truck(Car):
    def __init__(self, capacity):
        super().__init__(car_id, coordinates, driver)
        self.capacity = capacity

    def start_transportation()
        pass

    def finidh_transportation()
        pass

class Medium_Truck(Car):
    def __init__(self, capacity):
        super().__init__(car_id, coordinates, driver)
        self.capacity = capacity

    def start_transportation()
        pass

    def finidh_transportation()
        pass

class Big_Truck(Car):
    def __init__(self, capacity):
        super().__init__(car_id, coordinates, driver)
        self.capacity = capacity

    def start_transportation()
        pass

    def finidh_transportation()
        pass

class Special_Truck(Car):
    def __init__(self, capacity):
        super().__init__(car_id, coordinates, driver, cargo)
        self.capacity = capacity
        self.cargo = cargo

    def start_transportation()
        pass

    def finidh_transportation()
        pass

class Company_car(Car):
    def __init__(self):
        super().__init__(car_id, coordinates, driver)

    def start_run()
        pass

    def finidh_run()
        pass

class Coordinates:
    def __init__(self, x, y):
        self.x = x
        self.y = y
